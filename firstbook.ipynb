# %%
d = {'file1':52,'file2':32,'file3':60,'file4':100}
print (d)
# Out:
# {'file1': 52, 'file2': 32, 'file3': 60, 'file4': 100}

# %%
import os

for file in os.listdir("."):
    print (file)
# Out:
# firstbook.ipynb

# %%
sortedFileDeatils = dict(sorted(d.items(), key=lambda x: x[1], reverse=True))

# %%
print(list(sortedFileDEatils.items())[0:2])
# Out:
# [('file4', 100), ('file3', 60)]

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.bar(sortedFileDeatils.keys(),sortedFileDeatils.values())
ax.set_ylabel("#Log lines")
ax.set_xlabel("File name")
ax.set_title("Number of Log lines per java file")
plt.show()
